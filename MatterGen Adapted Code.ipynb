# %%
# Install a matched triad from the cu121 index (works with Python 3.12)
# !pip install -q --index-url https://download.pytorch.org/whl/cu121 \
  torch==2.7.1+cu121 torchvision==0.19.1+cu121 torchaudio==2.7.1+cu121

import torch, platform
print("Python:", platform.python_version())
print("Torch:", torch.__version__, "| CUDA avail:", torch.cuda.is_available(), "| CUDA:", torch.version.cuda)
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==2.7.1+cu121 (from versions: 2.2.0+cu121, 2.2.1+cu121, 2.2.2+cu121, 2.3.0+cu121, 2.3.1+cu121, 2.4.0+cu121, 2.4.1+cu121, 2.5.0+cu121, 2.5.1+cu121)
# ERROR: No matching distribution found for torch==2.7.1+cu121
# Python: 3.12.12
# Torch: 2.8.0+cu126 | CUDA avail: True | CUDA: 12.6

# %%
# !pip install -q fire hydra-core==1.3.1 hydra-joblib-launcher==1.1.5
# !pip install -q einops transformers accelerate safetensors tqdm requests contextlib2 lmdb SMACT
# Pin a few libs to what MatterGen expects
# !pip install -q "ase==3.25.0" "matplotlib==3.8.4" "monty==2024.7.30"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# WARNING: pandarallel 1.6.5 does not provide the extra 'optional'
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.4/299.4 kB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 82.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 124.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 108.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.3/82.3 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 8.3 MB/s eta 0:00:00
# ...

# %%
# !apt-get -y -qq install git-lfs
# !git lfs install

# !git clone https://github.com/microsoft/mattergen.git
# %cd mattergen

# keep your working Torch (2.8.0+cu126); don't pull MatterGen's pinned deps
# !pip install -q --no-deps -e .
# Out:
# Git LFS initialized.
# Cloning into 'mattergen'...
# remote: Enumerating objects: 1660, done.
# remote: Counting objects: 100% (407/407), done.
# remote: Compressing objects: 100% (164/164), done.
# remote: Total 1660 (delta 302), reused 243 (delta 243), pack-reused 1253 (from 2)
# Receiving objects: 100% (1660/1660), 3.38 MiB | 25.83 MiB/s, done.
# Resolving deltas: 100% (657/657), done.
# /content/mattergen
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for mattergen (pyproject.toml) ... done

# %%
# !git lfs pull -I checkpoints/mattergen_base --exclude=""
# !ls -lh checkpoints || true
# Out:
# total 36K
# drwxr-xr-x 3 root root 4.0K Oct 23 21:25 chemical_system
# drwxr-xr-x 3 root root 4.0K Oct 23 21:25 chemical_system_energy_above_hull
# drwxr-xr-x 3 root root 4.0K Oct 23 21:25 dft_band_gap
# drwxr-xr-x 3 root root 4.0K Oct 23 21:25 dft_mag_density
# drwxr-xr-x 3 root root 4.0K Oct 23 21:25 dft_mag_density_hhi_score
# drwxr-xr-x 3 root root 4.0K Oct 23 21:25 mattergen_base
# drwxr-xr-x 3 root root 4.0K Oct 23 21:25 ml_bulk_modulus
# drwxr-xr-x 3 root root 4.0K Oct 23 21:25 mp_20_base
# drwxr-xr-x 3 root root 4.0K Oct 23 21:25 space_group

# %%
# !pip install -q pytorch-lightning==2.0.6

# !pip install -q "numpy==1.26.4"

# Core PyG metapackage
# !pip install -q torch_geometric

# CUDA ops matching your current Torch (2.8.0+cu126)
# !pip install -q torch-scatter torch-sparse torch-cluster \
  -f https://data.pyg.org/whl/torch-2.8.0+cu126.html

# Install missing dependency
# !pip install -q emmet-core

# Try generation again
# !mkdir -p results
# !mattergen-generate results/ --pretrained-name=mattergen_base --batch_size=1 --num_batches=1
# !ls -lh results
# Out:
# MODELS_PROJECT_ROOT: /content/mattergen/mattergen
#
# Model config:
# /content/mattergen/mattergen/common/utils/data_classes.py:96: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   with initialize_config_dir(str(self.model_path)):
# auto_resume: true
# checkpoint_path: null
# data_module:
#   _recursive_: true
#   _target_: mattergen.common.data.datamodule.CrystDataModule
#   average_density: 0.05771451654022283
#   batch_size:
#     train: 32
#     val: 32
#   max_epochs: 2200
#   num_workers:
#     train: 0
#     val: 0
#   properties:
#   - dft_bulk_modulus
#   - dft_band_gap
#   - dft_mag_density
#   - ml_bulk_modulus
#   - hhi_score
#   - space_group
#   - energy_above_hull
#   root_dir: datasets/cache/alex_mp_20/
#   train_dataset:
#     _target_: mattergen.common.data.dataset.CrystalDataset.from_cache_path
#     cache_path: datasets/cache/alex_mp_20/train
# ...

# %%
# !mkdir -p results
# !mattergen-generate results/ --pretrained-name=mattergen_base --batch_size=1 --num_batches=1
# !ls -lh results
# Out:
# MODELS_PROJECT_ROOT: /content/mattergen/mattergen
#
# Model config:
# /content/mattergen/mattergen/common/utils/data_classes.py:96: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   with initialize_config_dir(str(self.model_path)):
# auto_resume: true
# checkpoint_path: null
# data_module:
#   _recursive_: true
#   _target_: mattergen.common.data.datamodule.CrystDataModule
#   average_density: 0.05771451654022283
#   batch_size:
#     train: 32
#     val: 32
#   max_epochs: 2200
#   num_workers:
#     train: 0
#     val: 0
#   properties:
#   - dft_bulk_modulus
#   - dft_band_gap
#   - dft_mag_density
#   - ml_bulk_modulus
#   - hhi_score
#   - space_group
#   - energy_above_hull
#   root_dir: datasets/cache/alex_mp_20/
#   train_dataset:
#     _target_: mattergen.common.data.dataset.CrystalDataset.from_cache_path
#     cache_path: datasets/cache/alex_mp_20/train
# ...

# %%
# !mattergen-generate results/raw \
  --pretrained-name chemical_system \
  -- \
  chemical_system "Ta Cr O" \
  --batch_size 1 --num_batches 3
# Out:
# MODELS_PROJECT_ROOT: /content/mattergen/mattergen
#
# Model config:
# /content/mattergen/mattergen/common/utils/data_classes.py:96: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   with initialize_config_dir(str(self.model_path)):
# adapter:
#   adapter:
#     _target_: mattergen.adapter.GemNetTAdapter
#     atom_type_diffusion: mask
#     denoise_atom_types: true
#     gemnet:
#       _target_: mattergen.common.gemnet.gemnet_ctrl.GemNetTCtrl
#       atom_embedding:
#         _target_: mattergen.common.gemnet.layers.embedding_block.AtomEmbedding
#         emb_size: 512
#         with_mask_type: true
#       condition_on_adapt:
#       - chemical_system
#       cutoff: 7.0
#       emb_size_atom: 512
#       emb_size_edge: 512
#       latent_dim: 512
#       max_cell_images_per_dim: 5
#       max_neighbors: 50
#       num_blocks: 4
#       num_targets: 1
# ...
